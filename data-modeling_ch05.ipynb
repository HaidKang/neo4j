# %%
# %load_ext icypher
# Out:
# The icypher extension is already loaded. To reload it, use:
#   %reload_ext icypher

# %%
# %cypher http://neo4j:neo4jadmin@localhost:7474/db/data

# %% [markdown]
# # 4장 Summary
# > RDBMS를 사용하여 전통적으로 구현된 도메인을 모델링하는 방법
# > 테이블이 노드와 관계로 변경되는 방법
# > Cypher의 트랜잭션에 대해 배우고 데이터베이스를 조작하기 위해 Cypher를 작성

# %% [markdown]
# # 5장 Refactoring the Data Model 주제
# > 1. 비즈니스 요구 사항에 맞게 데이터 모델 수정
# > 2. 이전 모델에서 새 모델로 데이터 마이그레이션

# %% [markdown]
# ## 1. Capturing information about hotels at airports
# 여행 중 경유 시간이 6시간 이상이라면 여행자는 일반적으로 휴식이 필요하다.
# 여행자가 경유하는 국가의 비자가 없을 수 있으므로 대부분의 기숙사나 호텔은 공항 내에 있다.
# 여행자가 공항에 있는 호텔에 대한 정보를 이용하여 여행을 더 잘 계획할 수 있다.
# 한 도시에 공항이 여러 개 있으므로 여행자가 경유하는 공항에 위치한 호텔만 표시하는 것은 필수이다.

# %% [markdown]
# ## 2. Modeling airports and hotels
# > • 여행자가 경유하는 공항에 위치한 호텔만 표시하려면 공항을 모델링해야 한다
# > • 현재 공항은 항공편 정보의 일부이기 때문에 변경이 필요하다.
# > • 그림 5.1과 같이 공항 정보(즉, airport_code)를 :Airport라는 레이블이 붙은 별도의 노드로 추출한다
# > • Property code는 공항의 고유 식별자 역할을 한다

# %% [markdown]
# ![figure%205-1.png](attachment:figure%205-1.png)
#
# >> price 는 비교할 수 있으므로 숫자로 저장

# %% [markdown]
# City, Airport, Hotel 구조 지정
# ![figure%205-2.png](attachment:figure%205-2.png)

# %% [markdown]
# ## 3. Extracting airport information from flight
#
# > ### 항공편에서 공항 정보 추출 : Flight Prperty 인 Airport  --> 실체로 변경 ( Node )

# %% [markdown]
# ### 3.1. Creating airport

# %% [markdown]
# snippet_1.txt : Airport 제약 조건 생성

# %%
# %%cypher
# CREATE CONSTRAINT ON (airport:Airport) ASSERT airport.code IS UNIQUE;
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-8-7389ebe0012f> in <module>
# ----> 1 get_ipython().run_cell_magic('cypher', '', 'CREATE CONSTRAINT ON (airport:Airport) ASSERT airport.code IS UNIQUE;\n')
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2380             with self.builtin_trap:
#    2381                 args = (magic_arg_s, cell)
# -> 2382                 result = fn(*args, **kwargs)
#    2383             return result
#    2384
#
# <decorator-gen-119> in cypher(self, line, cell)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-118> in cypher(self, line, cell)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\icypher\__init__.py in cypher(self, line, cell)
#     157
#     158         if parsed['query']:
# --> 159             return self.db.run(parsed['query']).data()
#     160
#     161 def load_ipython_extension(ip):
#
# C:\ProgramData\Anaconda3\lib\site-packages\py2neo\database.py in run(self, cypher, parameters, **kwparameters)
#     403         :return:
#     404         """
# --> 405         return self.auto().run(cypher, parameters, **kwparameters)
#     406
#     407     def evaluate(self, cypher, parameters=None, **kwparameters):
#
# C:\ProgramData\Anaconda3\lib\site-packages\py2neo\database.py in run(self, cypher, parameters, **kwparameters)
#     987                 result = self._connector.run(self.ref, cypher, parameters)
#     988             else:
# --> 989                 result = self._connector.auto_run(cypher, parameters,
#     990                                                   graph_name=self.graph.name,
#     991                                                   readonly=self.readonly)
#
# C:\ProgramData\Anaconda3\lib\site-packages\py2neo\client\__init__.py in auto_run(self, cypher, parameters, graph_name, readonly)
#    1338         cx = self._acquire(graph_name)
#    1339         try:
# -> 1340             return cx.auto_run(cypher, parameters, graph_name=graph_name, readonly=readonly)
#    1341         except (ConnectionUnavailable, ConnectionBroken):
#    1342             self.prune(cx.profile)
#
# C:\ProgramData\Anaconda3\lib\site-packages\py2neo\client\http.py in auto_run(self, cypher, parameters, graph_name, readonly)
#     176             r = self._post(HTTPTransactionRef.autocommit_uri(graph_name), cypher, parameters)
#     177             rs = HTTPResponse.from_json(r.status, r.data.decode("utf-8"))
# --> 178             rs.audit()
#     179             return HTTPResult(HTTPTransactionRef(graph_name), rs.result(), profile=self.profile)
#     180         finally:
#
# C:\ProgramData\Anaconda3\lib\site-packages\py2neo\client\http.py in audit(self, tx)
#     480             if tx is not None:
#     481                 tx.mark_broken()
# --> 482             raise failure
#
# ClientError: [Schema.EquivalentSchemaRuleAlreadyExists] An equivalent constraint already exists, 'Constraint( id=17, name='constraint_6cdab53a', type='UNIQUENESS', schema=(:Airport {code}), ownedIndex=16 )'.

# %% [markdown]
# ### 3.2. Breaking airports out as a node ( 공항을 노드로 분리)

# %% [markdown]
# flight source_airport_code, destination_airport_ 코드 property ==> node<br><br>
# :HAS_FLIGHT 와 :FLYING_TO 관계 변화 필요: (:Flight) - (:City)  ==> (:Flight) - (:Airport)

# %% [markdown]
# ![figure%205-3.png](attachment:figure%205-3.png)

# %% [markdown]
# snippet_2.txt : fight 로 부터 airport 생성

# %%
# %%cypher
# MATCH (source:City)-[:HAS_FLIGHT]->(f:Flight)-[:FLYING_TO]->(destination:City)
# WITH source, f, destination
# MERGE (source_airport:Airport{code: f.source_airport_code})
# MERGE (destination_airport:Airport{code: f.destination_airport_code})
# WITH source, destination, source_airport, destination_airport
# MERGE (source)-[:HAS_AIRPORT]->(source_airport)
# MERGE (destination)-[:HAS_AIRPORT]->(destination_airport)
# RETURN source, destination, source_airport, destination_airport
# Out:
# [{'source': Node('City', country='Singapore', name='Singapore'),
#   'destination': Node('City', country='India', name='Mumbai'),
#   'source_airport': Node('Airport', code='SIN'),
#   'destination_airport': Node('Airport', code='BOM')},
#  {'source': Node('City', country='Singapore', name='Singapore'),
#   'destination': Node('City', country='India', name='Mumbai'),
#   'source_airport': Node('Airport', code='SIN'),
#   'destination_airport': Node('Airport', code='BOM')},
#  {'source': Node('City', country='United Kingdom', name='London'),
#   'destination': Node('City', country='India', name='Mumbai'),
#   'source_airport': Node('Airport', code='LHR'),
#   'destination_airport': Node('Airport', code='BOM')},
#  {'source': Node('City', country='United Kingdom', name='London'),
#   'destination': Node('City', country='India', name='Mumbai'),
#   'source_airport': Node('Airport', code='LHR'),
#   'destination_airport': Node('Airport', code='BOM')},
#  {'source': Node('City', country='United States of America', name='New York'),
#   'destination': Node('City', country='India', name='Mumbai'),
#   'source_airport': Node('Airport', code='EWR'),
#   'destination_airport': Node('Airport', code='BOM')},
#  {'source': Node('City', country='United States of America', name='New York'),
#   'destination': Node('City', country='India', name='Mumbai'),
#   'source_airport': Node('Airport', code='EWR'),
#   'destination_airport': Node('Airport', code='BOM')},
#  {'source': Node('City', country='United States of America', name='New York'),
#   'destination': Node('City', country='United States of America', name='Chicago'),
#   'source_airport': Node('Airport', code='LGA'),
#   'destination_airport': Node('Airport', code='ORD')},
#  {'source': Node('City', country='United States of America', name='New York'),
#   'destination': Node('City', country='United States of America', name='Chicago'),
#   'source_airport': Node('Airport', code='JFK'),
#   'destination_airport': Node('Airport', code='ORD')},
#  {'source': Node('City', country='United States of America', name='Los Angeles'),
#   'destination': Node('City', country='United States of America', name='Las Vegas'),
#   'source_airport': Node('Airport', code='LAX'),
#   'destination_airport': Node('Airport', code='LAS')},
#  {'source': Node('City', country='United States of America', name='Los Angeles'),
#   'destination': Node('City', country='United States of America', name='Las Vegas'),
#   'source_airport': Node('Airport', code='LAX'),
#   'destination_airport': Node('Airport', code='LAS')},
#  {'source': Node('City', country='United States of America', name='New York'),
#   'destination': Node('City', country='United States of America', name='Las Vegas'),
#   'source_airport': Node('Airport', code='EWR'),
#   'destination_airport': Node('Airport', code='LAS')},
#  {'source': Node('City', country='United States of America', name='New York'),
#   'destination': Node('City', country='United States of America', name='Las Vegas'),
#   'source_airport': Node('Airport', code='EWR'),
#   'destination_airport': Node('Airport', code='LAS')},
#  {'source': Node('City', country='Australia', name='Melbourne'),
#   'destination': Node('City', country='United States of America', name='Los Angeles'),
#   'source_airport': Node('Airport', code='MEL'),
#   'destination_airport': Node('Airport', code='LAX')},
#  {'source': Node('City', country='Australia', name='Melbourne'),
#   'destination': Node('City', country='United States of America', name='Los Angeles'),
#   'source_airport': Node('Airport', code='MEL'),
#   'destination_airport': Node('Airport', code='LAX')},
#  {'source': Node('City', country='United States of America', name='Las Vegas'),
#   'destination': Node('City', country='United States of America', name='Los Angeles'),
#   'source_airport': Node('Airport', code='LAS'),
#   'destination_airport': Node('Airport', code='LAX')},
#  {'source': Node('City', country='United States of America', name='Las Vegas'),
#   'destination': Node('City', country='United States of America', name='Los Angeles'),
#   'source_airport': Node('Airport', code='LAS'),
#   'destination_airport': Node('Airport', code='LAX')},
#  {'source': Node('City', country='United States of America', name='New York'),
#   'destination': Node('City', country='United States of America', name='Los Angeles'),
#   'source_airport': Node('Airport', code='JFK'),
#   'destination_airport': Node('Airport', code='LAX')},
#  {'source': Node('City', country='United States of America', name='New York'),
#   'destination': Node('City', country='United States of America', name='Los Angeles'),
#   'source_airport': Node('Airport', code='JFK'),
#   'destination_airport': Node('Airport', code='LAX')},
#  {'source': Node('City', country='United States of America', name='New York'),
#   'destination': Node('City', country='Canada', name='Toronto'),
#   'source_airport': Node('Airport', code='JFK'),
#   'destination_airport': Node('Airport', code='YYZ')},
#  {'source': Node('City', country='United States of America', name='New York'),
#   'destination': Node('City', country='Canada', name='Toronto'),
#   'source_airport': Node('Airport', code='EWR'),
#   'destination_airport': Node('Airport', code='YYZ')},
#  {'source': Node('City', country='India', name='Mumbai'),
#   'destination': Node('City', country='United Kingdom', name='London'),
#   'source_airport': Node('Airport', code='BOM'),
#   'destination_airport': Node('Airport', code='LHR')},
#  {'source': Node('City', country='India', name='Mumbai'),
#   'destination': Node('City', country='United Kingdom', name='London'),
#   'source_airport': Node('Airport', code='BOM'),
#   'destination_airport': Node('Airport', code='LHR')},
#  {'source': Node('City', country='Greece', name='Athens'),
#   'destination': Node('City', country='United Kingdom', name='London'),
#   'source_airport': Node('Airport', code='ATH'),
#   'destination_airport': Node('Airport', code='LHR')},
#  {'source': Node('City', country='Greece', name='Athens'),
#   'destination': Node('City', country='United Kingdom', name='London'),
#   'source_airport': Node('Airport', code='ATH'),
#   'destination_airport': Node('Airport', code='LHR')},
#  {'source': Node('City', country='Turkey', name='Istanbul'),
#   'destination': Node('City', country='United Kingdom', name='London'),
#   'source_airport': Node('Airport', code='SAW'),
#   'destination_airport': Node('Airport', code='LGW')},
#  {'source': Node('City', country='Turkey', name='Istanbul'),
#   'destination': Node('City', country='United Kingdom', name='London'),
#   'source_airport': Node('Airport', code='SAW'),
#   'destination_airport': Node('Airport', code='LHR')},
#  {'source': Node('City', country='France', name='Paris'),
#   'destination': Node('City', country='United Kingdom', name='London'),
#   'source_airport': Node('Airport', code='CDG'),
#   'destination_airport': Node('Airport', code='LHR')},
#  {'source': Node('City', country='France', name='Paris'),
#   'destination': Node('City', country='United Kingdom', name='London'),
#   'source_airport': Node('Airport', code='CDG'),
#   'destination_airport': Node('Airport', code='LHR')},
#  {'source': Node('City', country='Spain', name='Madrid'),
#   'destination': Node('City', country='United Kingdom', name='London'),
#   'source_airport': Node('Airport', code='MAD'),
#   'destination_airport': Node('Airport', code='LGW')},
#  {'source': Node('City', country='Spain', name='Madrid'),
#   'destination': Node('City', country='United Kingdom', name='London'),
#   'source_airport': Node('Airport', code='MAD'),
#   'destination_airport': Node('Airport', code='LGW')},
#  {'source': Node('City', country='United States of America', name='New York'),
#   'destination': Node('City', country='United Kingdom', name='London'),
#   'source_airport': Node('Airport', code='JFK'),
#   'destination_airport': Node('Airport', code='LHR')},
#  {'source': Node('City', country='United States of America', name='New York'),
#   'destination': Node('City', country='United Kingdom', name='London'),
#   'source_airport': Node('Airport', code='JFK'),
#   'destination_airport': Node('Airport', code='LHR')},
#  {'source': Node('City', country='United Kingdom', name='London'),
#   'destination': Node('City', country='Spain', name='Madrid'),
#   'source_airport': Node('Airport', code='LGW'),
#   'destination_airport': Node('Airport', code='MAD')},
#  {'source': Node('City', country='United Kingdom', name='London'),
#   'destination': Node('City', country='Spain', name='Madrid'),
#   'source_airport': Node('Airport', code='LGW'),
#   'destination_airport': Node('Airport', code='MAD')},
#  {'source': Node('City', country='Italy', name='Rome'),
#   'destination': Node('City', country='France', name='Paris'),
#   'source_airport': Node('Airport', code='FCO'),
#   'destination_airport': Node('Airport', code='CDG')},
#  {'source': Node('City', country='Italy', name='Rome'),
#   'destination': Node('City', country='France', name='Paris'),
#   'source_airport': Node('Airport', code='FCO'),
#   'destination_airport': Node('Airport', code='CDG')},
#  {'source': Node('City', country='Greece', name='Athens'),
#   'destination': Node('City', country='France', name='Paris'),
#   'source_airport': Node('Airport', code='ATH'),
#   'destination_airport': Node('Airport', code='CDG')},
#  {'source': Node('City', country='Greece', name='Athens'),
#   'destination': Node('City', country='France', name='Paris'),
#   'source_airport': Node('Airport', code='ATH'),
#   'destination_airport': Node('Airport', code='CDG')},
#  {'source': Node('City', country='United Kingdom', name='London'),
#   'destination': Node('City', country='France', name='Paris'),
#   'source_airport': Node('Airport', code='LHR'),
#   'destination_airport': Node('Airport', code='CDG')},
#  {'source': Node('City', country='United Kingdom', name='London'),
#   'destination': Node('City', country='France', name='Paris'),
#   'source_airport': Node('Airport', code='LHR'),
#   'destination_airport': Node('Airport', code='CDG')},
#  {'source': Node('City', country='United States of America', name='New York'),
#   'destination': Node('City', country='France', name='Paris'),
#   'source_airport': Node('Airport', code='JFK'),
#   'destination_airport': Node('Airport', code='CDG')},
#  {'source': Node('City', country='United States of America', name='New York'),
#   'destination': Node('City', country='France', name='Paris'),
#   'source_airport': Node('Airport', code='JFK'),
#   'destination_airport': Node('Airport', code='CDG')},
#  {'source': Node('City', country='Italy', name='Rome'),
#   'destination': Node('City', country='Greece', name='Athens'),
#   'source_airport': Node('Airport', code='CIA'),
#   'destination_airport': Node('Airport', code='ATH')},
#  {'source': Node('City', country='Italy', name='Rome'),
#   'destination': Node('City', country='Greece', name='Athens'),
#   'source_airport': Node('Airport', code='FCO'),
#   'destination_airport': Node('Airport', code='ATH')},
#  {'source': Node('City', country='Turkey', name='Istanbul'),
#   'destination': Node('City', country='Greece', name='Athens'),
#   'source_airport': Node('Airport', code='IST'),
#   'destination_airport': Node('Airport', code='ATH')},
#  {'source': Node('City', country='Turkey', name='Istanbul'),
#   'destination': Node('City', country='Greece', name='Athens'),
#   'source_airport': Node('Airport', code='IST'),
#   'destination_airport': Node('Airport', code='ATH')},
#  {'source': Node('City', country='France', name='Paris'),
#   'destination': Node('City', country='Greece', name='Athens'),
#   'source_airport': Node('Airport', code='CDG'),
#   'destination_airport': Node('Airport', code='ATH')},
#  {'source': Node('City', country='France', name='Paris'),
#   'destination': Node('City', country='Greece', name='Athens'),
#   'source_airport': Node('Airport', code='CDG'),
#   'destination_airport': Node('Airport', code='ATH')},
#  {'source': Node('City', country='United Kingdom', name='London'),
#   'destination': Node('City', country='Greece', name='Athens'),
#   'source_airport': Node('Airport', code='LHR'),
#   'destination_airport': Node('Airport', code='ATH')},
#  {'source': Node('City', country='United Kingdom', name='London'),
#   'destination': Node('City', country='Greece', name='Athens'),
#   'source_airport': Node('Airport', code='LHR'),
#   'destination_airport': Node('Airport', code='ATH')},
#  {'source': Node('City', country='Greece', name='Athens'),
#   'destination': Node('City', country='Italy', name='Rome'),
#   'source_airport': Node('Airport', code='ATH'),
#   'destination_airport': Node('Airport', code='CIA')},
#  {'source': Node('City', country='Greece', name='Athens'),
#   'destination': Node('City', country='Italy', name='Rome'),
#   'source_airport': Node('Airport', code='ATH'),
#   'destination_airport': Node('Airport', code='FCO')},
#  {'source': Node('City', country='France', name='Paris'),
#   'destination': Node('City', country='Italy', name='Rome'),
#   'source_airport': Node('Airport', code='CDG'),
#   'destination_airport': Node('Airport', code='FCO')},
#  {'source': Node('City', country='France', name='Paris'),
#   'destination': Node('City', country='Italy', name='Rome'),
#   'source_airport': Node('Airport', code='CDG'),
#   'destination_airport': Node('Airport', code='FCO')},
#  {'source': Node('City', country='United States of America', name='New York'),
#   'destination': Node('City', country='Italy', name='Rome'),
#   'source_airport': Node('Airport', code='JFK'),
#   'destination_airport': Node('Airport', code='FCO')},
#  {'source': Node('City', country='United States of America', name='New York'),
#   'destination': Node('City', country='Italy', name='Rome'),
#   'source_airport': Node('Airport', code='JFK'),
#   'destination_airport': Node('Airport', code='FCO')},
#  {'source': Node('City', country='Greece', name='Athens'),
#   'destination': Node('City', country='Turkey', name='Istanbul'),
#   'source_airport': Node('Airport', code='ATH'),
#   'destination_airport': Node('Airport', code='IST')},
#  {'source': Node('City', country='Greece', name='Athens'),
#   'destination': Node('City', country='Turkey', name='Istanbul'),
#   'source_airport': Node('Airport', code='ATH'),
#   'destination_airport': Node('Airport', code='IST')},
#  {'source': Node('City', country='United Kingdom', name='London'),
#   'destination': Node('City', country='Turkey', name='Istanbul'),
#   'source_airport': Node('Airport', code='LGW'),
#   'destination_airport': Node('Airport', code='SAW')},
#  {'source': Node('City', country='United Kingdom', name='London'),
#   'destination': Node('City', country='Turkey', name='Istanbul'),
#   'source_airport': Node('Airport', code='LHR'),
#   'destination_airport': Node('Airport', code='SAW')},
#  {'source': Node('City', country='Australia', name='Sydney'),
#   'destination': Node('City', country='Singapore', name='Singapore'),
#   'source_airport': Node('Airport', code='SYD'),
#   'destination_airport': Node('Airport', code='SIN')},
#  {'source': Node('City', country='Australia', name='Sydney'),
#   'destination': Node('City', country='Singapore', name='Singapore'),
#   'source_airport': Node('Airport', code='SYD'),
#   'destination_airport': Node('Airport', code='SIN')},
#  {'source': Node('City', country='Australia', name='Melbourne'),
#   'destination': Node('City', country='Singapore', name='Singapore'),
#   'source_airport': Node('Airport', code='MEL'),
#   'destination_airport': Node('Airport', code='SIN')},
#  {'source': Node('City', country='India', name='Mumbai'),
#   'destination': Node('City', country='Singapore', name='Singapore'),
#   'source_airport': Node('Airport', code='BOM'),
#   'destination_airport': Node('Airport', code='SIN')},
#  {'source': Node('City', country='India', name='Mumbai'),
#   'destination': Node('City', country='Singapore', name='Singapore'),
#   'source_airport': Node('Airport', code='BOM'),
#   'destination_airport': Node('Airport', code='SIN')},
#  {'source': Node('City', country='Australia', name='Melbourne'),
#   'destination': Node('City', country='Australia', name='Sydney'),
#   'source_airport': Node('Airport', code='MEL'),
#   'destination_airport': Node('Airport', code='SYD')},
#  {'source': Node('City', country='Australia', name='Melbourne'),
#   'destination': Node('City', country='Australia', name='Sydney'),
#   'source_airport': Node('Airport', code='MEL'),
#   'destination_airport': Node('Airport', code='SYD')},
#  {'source': Node('City', country='Singapore', name='Singapore'),
#   'destination': Node('City', country='Australia', name='Sydney'),
#   'source_airport': Node('Airport', code='SIN'),
#   'destination_airport': Node('Airport', code='SYD')},
#  {'source': Node('City', country='Singapore', name='Singapore'),
#   'destination': Node('City', country='Australia', name='Sydney'),
#   'source_airport': Node('Airport', code='SIN'),
#   'destination_airport': Node('Airport', code='SYD')},
#  {'source': Node('City', country='Australia', name='Sydney'),
#   'destination': Node('City', country='Australia', name='Melbourne'),
#   'source_airport': Node('Airport', code='SYD'),
#   'destination_airport': Node('Airport', code='MEL')},
#  {'source': Node('City', country='Australia', name='Sydney'),
#   'destination': Node('City', country='Australia', name='Melbourne'),
#   'source_airport': Node('Airport', code='SYD'),
#   'destination_airport': Node('Airport', code='MEL')},
#  {'source': Node('City', country='Singapore', name='Singapore'),
#   'destination': Node('City', country='Australia', name='Melbourne'),
#   'source_airport': Node('Airport', code='SIN'),
#   'destination_airport': Node('Airport', code='MEL')},
#  {'source': Node('City', country='United States of America', name='Los Angeles'),
#   'destination': Node('City', country='Australia', name='Melbourne'),
#   'source_airport': Node('Airport', code='LAX'),
#   'destination_airport': Node('Airport', code='MEL')},
#  {'source': Node('City', country='United States of America', name='Los Angeles'),
#   'destination': Node('City', country='Australia', name='Melbourne'),
#   'source_airport': Node('Airport', code='LAX'),
#   'destination_airport': Node('Airport', code='MEL')},
#  {'source': Node('City', country='India', name='Mumbai'),
#   'destination': Node('City', country='United States of America', name='New York'),
#   'source_airport': Node('Airport', code='BOM'),
#   'destination_airport': Node('Airport', code='EWR')},
#  {'source': Node('City', country='India', name='Mumbai'),
#   'destination': Node('City', country='United States of America', name='New York'),
#   'source_airport': Node('Airport', code='BOM'),
#   'destination_airport': Node('Airport', code='EWR')},
#  {'source': Node('City', country='Italy', name='Rome'),
#   'destination': Node('City', country='United States of America', name='New York'),
#   'source_airport': Node('Airport', code='FCO'),
#   'destination_airport': Node('Airport', code='JFK')},
#  {'source': Node('City', country='Italy', name='Rome'),
#   'destination': Node('City', country='United States of America', name='New York'),
#   'source_airport': Node('Airport', code='FCO'),
#   'destination_airport': Node('Airport', code='JFK')},
#  {'source': Node('City', country='France', name='Paris'),
#   'destination': Node('City', country='United States of America', name='New York'),
#   'source_airport': Node('Airport', code='CDG'),
#   'destination_airport': Node('Airport', code='JFK')},
#  {'source': Node('City', country='France', name='Paris'),
#   'destination': Node('City', country='United States of America', name='New York'),
#   'source_airport': Node('Airport', code='CDG'),
#   'destination_airport': Node('Airport', code='JFK')},
#  {'source': Node('City', country='United Kingdom', name='London'),
#   'destination': Node('City', country='United States of America', name='New York'),
#   'source_airport': Node('Airport', code='LHR'),
#   'destination_airport': Node('Airport', code='JFK')},
#  {'source': Node('City', country='United Kingdom', name='London'),
#   'destination': Node('City', country='United States of America', name='New York'),
#   'source_airport': Node('Airport', code='LHR'),
#   'destination_airport': Node('Airport', code='JFK')},
#  {'source': Node('City', country='United States of America', name='Las Vegas'),
#   'destination': Node('City', country='United States of America', name='New York'),
#   'source_airport': Node('Airport', code='LAS'),
#   'destination_airport': Node('Airport', code='EWR')},
#  {'source': Node('City', country='United States of America', name='Las Vegas'),
#   'destination': Node('City', country='United States of America', name='New York'),
#   'source_airport': Node('Airport', code='LAS'),
#   'destination_airport': Node('Airport', code='EWR')},
#  {'source': Node('City', country='United States of America', name='Chicago'),
#   'destination': Node('City', country='United States of America', name='New York'),
#   'source_airport': Node('Airport', code='ORD'),
#   'destination_airport': Node('Airport', code='LGA')},
#  {'source': Node('City', country='United States of America', name='Chicago'),
#   'destination': Node('City', country='United States of America', name='New York'),
#   'source_airport': Node('Airport', code='ORD'),
#   'destination_airport': Node('Airport', code='JFK')},
#  {'source': Node('City', country='Canada', name='Toronto'),
#   'destination': Node('City', country='United States of America', name='New York'),
#   'source_airport': Node('Airport', code='YYZ'),
#   'destination_airport': Node('Airport', code='JFK')},
#  {'source': Node('City', country='Canada', name='Toronto'),
#   'destination': Node('City', country='United States of America', name='New York'),
#   'source_airport': Node('Airport', code='YYZ'),
#   'destination_airport': Node('Airport', code='EWR')},
#  {'source': Node('City', country='United States of America', name='Los Angeles'),
#   'destination': Node('City', country='United States of America', name='New York'),
#   'source_airport': Node('Airport', code='LAX'),
#   'destination_airport': Node('Airport', code='JFK')},
#  {'source': Node('City', country='United States of America', name='Los Angeles'),
#   'destination': Node('City', country='United States of America', name='New York'),
#   'source_airport': Node('Airport', code='LAX'),
#   'destination_airport': Node('Airport', code='JFK')}]

# %% [markdown]
# ![figure%205-4.png](attachment:figure%205-4.png)

# %% [markdown]
# ### 3.3. Connecting flights to airports

# %% [markdown]
# snippet_3.txt : airports 과 flights 연결

# %%
# %%cypher
# MATCH (f:Flight)
# WITH f
# MATCH (source_airport:Airport{code:f.source_airport_code}),
# (destination_airport:Airport{code:f.destination_airport_code})
# WITH  source_airport, destination_airport, f
# MERGE (source_airport)-[:HAS_FLIGHT]->(f)-[:FLYING_TO]->(destination_airport)
# RETURN source_airport, f, destination_airport

# %% [markdown]
# ![figure%205-5_%ED%9A%8C%EC%A0%84.png](attachment:figure%205-5_%ED%9A%8C%EC%A0%84.png)

# %% [markdown]
# ## 3.4. Delink flights and cities

# %% [markdown]
# snippet_4.txt : airports 과 cities 연결 해제, 출발지/목적지 코드를 null 로 설정

# %%
# %%cypher
# MATCH (f:Flight)-[r]-(:City)
# DELETE r
# SET f.source_airport_code = null, f.destination_airport_code = null;
# Out:
# []

# %% [markdown]
# ## 3.5. Querying the refactored data model

# %% [markdown]
# ![figure%205-6.png](attachment:figure%205-6.png)

# %% [markdown]
# 데이터모델 변경에 따라 script 변경
# > 3장 마지막 :
# >> MATCH path = (london:City{name:'London'})-[:HAS_FLIGHT|FLYING_TO*0..6]->(melbourne:City{name:'Melbourne'})
# >> WITH
# >> [f in nodes(path) WHERE  "Flight" IN labels(f)] as flights,
# >> [city in nodes(path) WHERE "City" IN labels(city)] as cities
# >> RETURN
# >> [city IN cities| city.name] as city,
# >> [flight IN flights| flight.code] as code,
# >> [flight IN flights| flight.carrier] as carrier,
# >> [flight IN flights| flight.departure] as departure,
# >> [flight IN flights| flight.arrival] as arrival,
# >> [flight IN flights| flight.duration] as duration,
# >> [flight IN flights| flight.source_airport_code] as from_airport,
# >> [flight IN flights| flight.destination_airport_code] as to_airport

# %% [markdown]
# snippet_5.txt : 변경된 query (데이모델이 변경 - 공항 추가 반영)

# %%
# %%cypher
# MATCH path = (london:City{name:'London'})-[:HAS_AIRPORT]->(:Airport)-[:HAS_FLIGHT|FLYING_TO*0..6]->(:Airport)<-[:HAS_AIRPORT]-(melbourne:City{name:'Melbourne'})
# WITH
# [f in nodes(path) WHERE  "Flight" IN labels(f)] as flights,
# [city in nodes(path) WHERE "City" IN labels(city)] as cities,
# [airport in nodes(path) WHERE "Airport" IN labels(airport)] as airports
# RETURN
# [city IN cities| city.name] as city,
# [flight IN flights| flight.code] as code,
# [flight IN flights| flight.carrier] as carrier,
# [flight IN flights| flight.departure] as departure,
# [flight IN flights| flight.arrival] as arrival,
# [flight IN flights| flight.duration] as duration,
# [airport IN airports| airport.code] as airport
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-11-cfcfa0bb0311> in <module>
# ----> 1 get_ipython().run_cell_magic('cypher', '', 'MATCH path = (london:City{name:\'London\'})-[:HAS_AIRPORT]->(:Airport)-[:HAS_FLIGHT|FLYING_TO*0..6]->(:Airport)<-[:HAS_AIRPORT]-(melbourne:City{name:\'Melbourne\'})\nWITH\n[f in nodes(path) WHERE  "Flight" IN labels(f)] as flights,\n[city in nodes(path) WHERE "City" IN labels(city)] as cities,\n[airport in nodes(path) WHERE "Airport" IN labels(airport)] as airports\nRETURN\n[city IN cities| city.name] as city,\n[flight IN flights| flight.code] as code,\n[flight IN flights| flight.carrier] as carrier,\n[flight IN flights| flight.departure] as departure,\n[flight IN flights| flight.arrival] as arrival,\n[flight IN flights| flight.duration] as duration,\n[airport IN airports| airport.code] as airport\n')
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2380             with self.builtin_trap:
#    2381                 args = (magic_arg_s, cell)
# -> 2382                 result = fn(*args, **kwargs)
#    2383             return result
#    2384
#
# <decorator-gen-119> in cypher(self, line, cell)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-118> in cypher(self, line, cell)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\icypher\__init__.py in cypher(self, line, cell)
#     157
#     158         if parsed['query']:
# --> 159             return self.db.run(parsed['query']).data()
#     160
#     161 def load_ipython_extension(ip):
#
# C:\ProgramData\Anaconda3\lib\site-packages\py2neo\database.py in run(self, cypher, parameters, **kwparameters)
#     403         :return:
#     404         """
# --> 405         return self.auto().run(cypher, parameters, **kwparameters)
#     406
#     407     def evaluate(self, cypher, parameters=None, **kwparameters):
#
# C:\ProgramData\Anaconda3\lib\site-packages\py2neo\database.py in run(self, cypher, parameters, **kwparameters)
#     987                 result = self._connector.run(self.ref, cypher, parameters)
#     988             else:
# --> 989                 result = self._connector.auto_run(cypher, parameters,
#     990                                                   graph_name=self.graph.name,
#     991                                                   readonly=self.readonly)
#
# C:\ProgramData\Anaconda3\lib\site-packages\py2neo\client\__init__.py in auto_run(self, cypher, parameters, graph_name, readonly)
#    1338         cx = self._acquire(graph_name)
#    1339         try:
# -> 1340             return cx.auto_run(cypher, parameters, graph_name=graph_name, readonly=readonly)
#    1341         except (ConnectionUnavailable, ConnectionBroken):
#    1342             self.prune(cx.profile)
#
# C:\ProgramData\Anaconda3\lib\site-packages\py2neo\client\http.py in auto_run(self, cypher, parameters, graph_name, readonly)
#     176             r = self._post(HTTPTransactionRef.autocommit_uri(graph_name), cypher, parameters)
#     177             rs = HTTPResponse.from_json(r.status, r.data.decode("utf-8"))
# --> 178             rs.audit()
#     179             return HTTPResult(HTTPTransactionRef(graph_name), rs.result(), profile=self.profile)
#     180         finally:
#
# C:\ProgramData\Anaconda3\lib\site-packages\py2neo\client\http.py in audit(self, tx)
#     480             if tx is not None:
#     481                 tx.mark_broken()
# --> 482             raise failure
#
# ClientError: [Statement.SyntaxError] Variable `Flight` not defined (line 3, column 25 (offset: 190))
# "[f in nodes(path) WHERE Flight IN labels(f)] as flights,"
#                          ^

# %% [markdown]
# ![figure%205-7.png](attachment:figure%205-7.png)

# %% [markdown]
# ## 4. Reasons for not migrating using a single query (단일 쿼리를 이용해 MIG 하지 않는이유)

# %% [markdown]
# 제약 조건을 만들고, 데이터를 변경하고, 관계를 한 번에 삭제하지 않는가?
# > 마이그레이션을 한번에 수행시 단점(제약 조건 생성, 데이터 변경, 관계 삭제 - 한 transaction ?) :<br>
# >> • 문제가 발생하면 함께 코드 rollback이 필요
# >> • 한번에 변경시 더 많은 테스트와 준비가 필요
#
# > 마이그레이션을 제약 조건 및 경로 생성과 관계 제거의 두 단계로 분리 이점 : <br>
# >> • 첫 번째 단계에서 제약 조건과 경로 생성. 충분한 시간을 확보하고 테스트 가능
# >> • 첫 번째 스크립트에 삭제 사항이 없으므로 잘못된 내용은 응용 프로그램의 안정성에 영향을 주지 않음
# >> • 두 번째 스크립트의 삭제는 응용 프로그램에서 사용할 하위 그래프에 영향을 미치지 않으므로 오류로 인해 응용 프로그램 다운타임이 발생하지 않음

# %% [markdown]
# ## 5. Adding hotels to airports

# %% [markdown]
# snippet_6.txt : hotels 에 constraints 추가

# %%
# %%cypher
# CREATE CONSTRAINT ON (hotel:Hotel) ASSERT hotel._id IS UNIQUE;

# %% [markdown]
# snippet_7.txt : hotels 를 추가하고, JFK airport에 연결

# %%
# %%cypher
# CREATE (hotel:Hotel {_id:"6ad8ce6e-1c0e-11e5-8db1-6c40089a9424",  name:"Hilton", price: 180})
# WITH hotel
# MATCH (airport:Airport{code:"JFK"})
# WITH airport, hotel
# MERGE (airport)-[:HAS_HOTEL]->(hotel)
# RETURN airport, hotel;
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-12-997b3ddfb274> in <module>
# ----> 1 get_ipython().run_cell_magic('cypher', '', 'CREATE (hotel:Hotel {_id:"6ad8ce6e-1c0e-11e5-8db1-6c40089a9424",  name:"Hilton", price: 180})\nWITH hotel\nMATCH (airport:Airport{code:"JFK"})\nWITH airport, hotel\nMERGE (airport)-[:HAS_HOTEL]->(hotel)\nRETURN airport, hotel;\n')
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2380             with self.builtin_trap:
#    2381                 args = (magic_arg_s, cell)
# -> 2382                 result = fn(*args, **kwargs)
#    2383             return result
#    2384
#
# <decorator-gen-119> in cypher(self, line, cell)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-118> in cypher(self, line, cell)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\icypher\__init__.py in cypher(self, line, cell)
#     157
#     158         if parsed['query']:
# --> 159             return self.db.run(parsed['query']).data()
#     160
#     161 def load_ipython_extension(ip):
#
# C:\ProgramData\Anaconda3\lib\site-packages\py2neo\database.py in run(self, cypher, parameters, **kwparameters)
#     403         :return:
#     404         """
# --> 405         return self.auto().run(cypher, parameters, **kwparameters)
#     406
#     407     def evaluate(self, cypher, parameters=None, **kwparameters):
#
# C:\ProgramData\Anaconda3\lib\site-packages\py2neo\database.py in run(self, cypher, parameters, **kwparameters)
#     987                 result = self._connector.run(self.ref, cypher, parameters)
#     988             else:
# --> 989                 result = self._connector.auto_run(cypher, parameters,
#     990                                                   graph_name=self.graph.name,
#     991                                                   readonly=self.readonly)
#
# C:\ProgramData\Anaconda3\lib\site-packages\py2neo\client\__init__.py in auto_run(self, cypher, parameters, graph_name, readonly)
#    1338         cx = self._acquire(graph_name)
#    1339         try:
# -> 1340             return cx.auto_run(cypher, parameters, graph_name=graph_name, readonly=readonly)
#    1341         except (ConnectionUnavailable, ConnectionBroken):
#    1342             self.prune(cx.profile)
#
# C:\ProgramData\Anaconda3\lib\site-packages\py2neo\client\http.py in auto_run(self, cypher, parameters, graph_name, readonly)
#     176             r = self._post(HTTPTransactionRef.autocommit_uri(graph_name), cypher, parameters)
#     177             rs = HTTPResponse.from_json(r.status, r.data.decode("utf-8"))
# --> 178             rs.audit()
#     179             return HTTPResult(HTTPTransactionRef(graph_name), rs.result(), profile=self.profile)
#     180         finally:
#
# C:\ProgramData\Anaconda3\lib\site-packages\py2neo\client\http.py in audit(self, tx)
#     480             if tx is not None:
#     481                 tx.mark_broken()
# --> 482             raise failure
#
# ClientError: [Statement.SyntaxError] invalid literal number (line 1, column 26 (offset: 25))
# "CREATE (hotel:Hotel {_id:6ad8ce6e-1c0e-11e5-8db1-6c40089a9424, name:Hilton, price: 180})"
#                           ^

# %% [markdown]
# ![figure%205-8.png](attachment:figure%205-8.png)

# %% [markdown]
# Hotels.cqy : 추가 호텔들 반영

# %%
# %%cyper
# // Hotels.cqy 파일 호텔들 추가 필요

# %% [markdown]
# ## 6. Fetching Hotels

# %% [markdown]
# snippet_8.txt : hotel 가져오기

# %%
# %%cypher
# MATCH (airport:Airport)-[:HAS_HOTEL]->(hotel:Hotel)
# WHERE airport.code IN ["JFK", "LAX"]
# RETURN airport.code, hotel.name, hotel.price;

# %% [markdown]
# ![figure%205-9.png](attachment:figure%205-9.png)
